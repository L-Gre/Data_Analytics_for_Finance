# %%
from libraries import *

# %%
# load data

investor_data_raw = pd.read_csv(os.path.join(project_path, 'investor_data.csv'))
investor_data_raw.head(3)
# Out:
#           investor   commit  deal_size  invite  rating int_rate  covenants  \
# 0    Goldman Sachs   Commit        300      40       2   Market          2
# 1    Deutsche Bank  Decline       1200     140       2   Market          2
# 2  Bank of America   Commit        900     130       3   Market          2
#
#    total_fees  fee_share   prior_tier  invite_tier
# 0          30        0.0  Participant   Bookrunner
# 1         115       20.1   Bookrunner  Participant
# 2          98       24.4   Bookrunner   Bookrunner

# %% [markdown]
# # Data Profiling

# %%
investor_data_raw.shape
# Out:
# (7289, 11)

# %%
# how does each variable influence investors to invest?
# hypothesise relationships within data

# %% [markdown]
# ## Histograms: spotting outliers

# %%
# create histograms for continuous variables

investor_data_raw.hist(figsize=(10,10))
plt.show()

# check for e.g. negative values e.g. 'fees'

# %%
investor_data = investor_data_raw

# %%
investor_data.to_pickle('investor_data_step_1.pkl')
