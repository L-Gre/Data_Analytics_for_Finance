# %%
# load libraries
from libraries import *

# load data
investor_data = pd.read_pickle('investor_data_step_1.pkl')

# %% [markdown]
# ## Cleaning: remove negative fees

# %%
investor_data = investor_data[investor_data['total_fees'] > 0]
print(investor_data.shape)
print(investor_data.shape)

# make histograms of cleaned data
investor_data.hist(figsize= (10,7))
plt.show()
# Out:
# (7233, 11)
# (7233, 11)

# %%
# export data for next step
investor_data.to_pickle('investor_data_step_2.pkl')
